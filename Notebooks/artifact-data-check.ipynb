# %%
# Notebooks/artifact-data-check.ipynb

# Cell 1: Load Data & Basic Overview
import pandas as pd

# Update the CSV path if needed
csv_file = "/Users/harshil/Developer/GitHub_Repos/FailFix/Data/processed/artifact_data_table_1.csv"
df = pd.read_csv(csv_file)

print("=== Basic Overview ===")
print(f"DataFrame Shape: {df.shape}\n")
print("First 5 rows:")
print(df.head(), "\n")
print("DataFrame Info:")
df.info()
# Out:
# === Basic Overview ===
# DataFrame Shape: (2552, 33)
#
# First 5 rows:
#                _created  _deleted                                     _etag  \
# 0  2018-08-24T08:01:18Z     False  f0ba3f7059f911957b0c99ba4b82c23455bbc734
# 1  2018-03-06T04:13:22Z     False  4349909dfe62bd5dd30c5b1b24951dbdc14a4f31
# 2  2024-08-07T18:02:14Z     False  00cdf9f45087d66089266c98c973a68807f07b99
# 3  2018-08-23T19:54:33Z     False  e34b1d72fc1818418aee37f14d5ba24955b2f6e0
# 4  2018-03-08T04:06:54Z     False  21036a72909701d2476809566e99151a89ef7907
#
#                         _id  \
# 0  5b7fbb4e37be5b494c9f9f0b
# 1  5a9e1562f1f70e072f3a6672
# 2  66b3b6a669c5cc913dc63b42
# 3  5b7f10f937be5b494c9f9bf3
# 4  5aa0b6def1f70e0f2d0ce13e
#
#                                               _links              _updated  \
# 0  {"collection": {"href": "artifacts", "title": ...  2024-07-02T16:30:43Z
# 1  {"collection": {"href": "artifacts", "title": ...  2024-07-02T16:29:29Z
# 2  {"collection": {"href": "artifacts", "title": ...  2024-09-04T00:03:49Z
# 3  {"collection": {"href": "artifacts", "title": ...  2024-07-02T16:31:17Z
# 4  {"collection": {"href": "artifacts", "title": ...  2024-07-02T16:30:36Z
#
#   added_version base_branch         branch build_system  ...  pr_num  \
# 0         1.0.0      master         master          NaN  ...    7113
# 1         1.0.0         NaN         master        Maven  ...      -1
# 2         1.2.6         NaN  issue-254-fix          NaN  ...     269
# 3         1.0.0         NaN      jw/naming        Maven  ...      -1
# 4         1.0.0         NaN         master        Maven  ...      -1
#
#                             repo                        repo_mined_version  \
# 0  wbond/package_control_channel  efabcb148a97bb217fbd0c75655bd885bf6ec06d
# 1          checkstyle/checkstyle  810b5e9ef81fb40d4f88f9dae86b930b2735e431
# 2           AgentOps-AI/agentops  640ca65c00b74ef7b3db9a9e723c77451e349d50
# 3                square/retrofit  f83564aa114792fb5367e6d31c54cd50ba71218a
# 4                traccar/traccar  a79386202fcf1feb86b7770cbbbcfe65fa4a95ca
#
#    reproduce_attempts reproduce_successes  reproduced  \
# 0                 5.0                 5.0       False
# 1                 5.0                 5.0        True
# 2                 3.0                 3.0        True
# 3                 5.0                 5.0        True
# 4                 5.0                 5.0        True
#
#                               reproducibility_status  stability  status  \
# 0  {"status": "Reproducible", "time_stamp": "2018...        5/5  active
# 1  {"status": "Reproducible", "time_stamp": "2018...        5/5  active
# 2  {"status": "Reproducible", "time_stamp": "2024...        3/3  active
# 3  {"status": "Reproducible", "time_stamp": "2018...        5/5  active
# 4  {"status": "Reproducible", "time_stamp": "2018...        5/5  active
#
#    test_framework
# 0        unittest
# 1             NaN
# 2          pytest
# 3           JUnit
# 4           JUnit
#
# [5 rows x 33 columns]
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2552 entries, 0 to 2551
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _created                2552 non-null   object
#  1   _deleted                2552 non-null   bool
#  2   _etag                   2552 non-null   object
#  3   _id                     2552 non-null   object
#  4   _links                  2552 non-null   object
#  5   _updated                2552 non-null   object
#  6   added_version           2552 non-null   object
#  7   base_branch             641 non-null    object
#  8   branch                  2552 non-null   object
#  9   build_system            1777 non-null   object
#  10  cached                  2552 non-null   bool
#  11  ci_service              2552 non-null   object
#  12  current_image_tag       2552 non-null   object
#  13  deprecated_version      0 non-null      float64
#  14  failed_job              2552 non-null   object
#  15  filtered_reason         0 non-null      float64
#  16  image_tag               2552 non-null   object
#  17  is_error_pass           2552 non-null   bool
#  18  lang                    2552 non-null   object
#  19  match                   2003 non-null   float64
#  20  merged_at               441 non-null    object
#  21  metrics                 2552 non-null   object
#  22  passed_job              2552 non-null   object
#  23  pr_num                  2552 non-null   int64
#  24  repo                    2552 non-null   object
#  25  repo_mined_version      2552 non-null   object
#  26  reproduce_attempts      2552 non-null   float64
#  27  reproduce_successes     2552 non-null   float64
#  28  reproduced              2552 non-null   bool
#  29  reproducibility_status  2552 non-null   object
#  30  stability               2552 non-null   object
#  31  status                  2552 non-null   object
#  32  test_framework          1422 non-null   object
# dtypes: bool(4), float64(5), int64(1), object(23)
# memory usage: 588.3+ KB

# %%
# Cell 2: Summary Statistics & Missing Values
print("\n=== Summary Statistics for Numeric Columns ===")
print(df.describe())

print("\n=== Missing Values per Column ===")
print(df.isnull().sum())
# Out:
# === Summary Statistics for Numeric Columns ===
#        deprecated_version  filtered_reason        match        pr_num  \
# count                 0.0              0.0  2003.000000   2552.000000
# mean                  NaN              NaN     0.999501    924.192790
# std                   NaN              NaN     0.022344   2191.062655
# min                   NaN              NaN     0.000000     -1.000000
# 25%                   NaN              NaN     1.000000     -1.000000
# 50%                   NaN              NaN     1.000000     -1.000000
# 75%                   NaN              NaN     1.000000    331.000000
# max                   NaN              NaN     1.000000  13830.000000
#
#        reproduce_attempts  reproduce_successes
# count         2552.000000          2552.000000
# mean             4.833856             4.795846
# std              0.550669             0.633148
# min              3.000000             1.000000
# 25%              5.000000             5.000000
# 50%              5.000000             5.000000
# 75%              5.000000             5.000000
# max              5.000000             5.000000
#
# === Missing Values per Column ===
# _created                     0
# _deleted                     0
# _etag                        0
# _id                          0
# _links                       0
# _updated                     0
# added_version                0
# base_branch               1911
# branch                       0
# build_system               775
# cached                       0
# ci_service                   0
# current_image_tag            0
# deprecated_version        2552
# failed_job                   0
# filtered_reason           2552
# image_tag                    0
# is_error_pass                0
# lang                         0
# match                      549
# merged_at                 2111
# metrics                      0
# passed_job                   0
# pr_num                       0
# repo                         0
# repo_mined_version           0
# reproduce_attempts           0
# reproduce_successes          0
# reproduced                   0
# reproducibility_status       0
# stability                    0
# status                       0
# test_framework            1130
# dtype: int64

# %%
# Cell 3: Check for Duplicate Rows
num_duplicates = df.duplicated().sum()
print("\n=== Duplicate Rows Check ===")
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# === Duplicate Rows Check ===
# Number of duplicate rows: 0

# %%
# Cell 4: Validate Timestamp Columns
from datetime import datetime

def parse_timestamp(ts_str):
    """Attempt to parse an ISO 8601 timestamp (format: YYYY-MM-DDTHH:MM:SSZ)."""
    try:
        return datetime.strptime(ts_str, '%Y-%m-%dT%H:%M:%SZ')
    except Exception:
        return None

# Validate 'failed_commit' timestamps
failed_parsed = df['failed_commit'].dropna().apply(parse_timestamp)
invalid_failed = failed_parsed.isnull().sum()

# Validate 'passed_commit' timestamps
passed_parsed = df['passed_commit'].dropna().apply(parse_timestamp)
invalid_passed = passed_parsed.isnull().sum()

print("\n=== Timestamp Validation ===")
print(f"Total 'failed_commit' entries (non-null): {df['failed_commit'].dropna().shape[0]}")
print(f"Invalid 'failed_commit' timestamps: {invalid_failed}")
print(f"Total 'passed_commit' entries (non-null): {df['passed_commit'].dropna().shape[0]}")
print(f"Invalid 'passed_commit' timestamps: {invalid_passed}")
# Out:
# === Timestamp Validation ===
# Total 'failed_commit' entries (non-null): 2529
# Invalid 'failed_commit' timestamps: 0
# Total 'passed_commit' entries (non-null): 2529
# Invalid 'passed_commit' timestamps: 0

# %%
# Cell 5: Analyze the 'time_to_fix_hours' Column
print("\n=== 'time_to_fix_hours' Summary Statistics ===")
print(df['time_to_fix_hours'].describe())

# Check for negative time values (which may be unexpected)
negative_time_count = df[df['time_to_fix_hours'] < 0].shape[0]
print(f"\nNumber of negative 'time_to_fix_hours' entries: {negative_time_count}")

# Identify potential outliers (for example, values that are very high)
# Here we compute the 99th percentile as one reference
percentile_99 = df['time_to_fix_hours'].quantile(0.99)
print(f"99th percentile of 'time_to_fix_hours': {percentile_99:.2f} hours")
# Out:
# === 'time_to_fix_hours' Summary Statistics ===
# count    2529.000000
# mean       22.854815
# std       200.418925
# min         0.000556
# 25%         0.135278
# 50%         0.453611
# 75%         3.701667
# max      5058.024444
# Name: time_to_fix_hours, dtype: float64
#
# Number of negative 'time_to_fix_hours' entries: 0
# 99th percentile of 'time_to_fix_hours': 318.98 hours

# %%
# Cell 6: Explore Categorical Variables (Language & Exceptions)
print("\n=== Unique Languages & Their Counts ===")
print(df['lang'].value_counts())

print("\n=== Unique Exceptions (Non-null) ===")
# Show unique exception strings from the 'exceptions' column (if any)
unique_exceptions = df['exceptions'].dropna().unique()
print(unique_exceptions)
# Out:
# === Unique Languages & Their Counts ===
# lang
# Java      1758
# Python     771
# Name: count, dtype: int64
#
# === Unique Exceptions (Non-null) ===
# ['AssertionError' 'ImportError' 'NullPointerException' 'AssertionFailure'
#  'ComparisonFailure' 'AttributeError'
#  'InterruptedIOException;RetrofitError' 'WantedButNotInvoked'
#  'JSONException;InvocationTargetException;IllegalArgumentException'
#  'ValueError' 'PipeRunException;NullPointerException;AssertionFailedError'
#  'AssertionError;NullPointerException;ComparisonFailure'
#  'ImportError;ValueError' 'ArrayIndexOutOfBoundsException'
#  'BusinessServiceException' 'AssertionFailedError'
#  'AssertionError;IllegalArgumentException' 'URLError;UnboundLocalError'
#  'ImportError;ModuleNotFoundError'
#  'DuplicateMappingException;BeanCreationException;IllegalStateException'
#  'NullPointerException;BuilderException;PersistenceException;Exception'
#  'SQLFeatureNotSupportedException' 'StringIndexOutOfBoundsException'
#  'IllegalStateException' 'UnboundLocalError' 'RuntimeError;AttributeError'
#  'FileNotFoundError' 'TypeError' 'NoSuchMethodException' 'PicklingError'
#  'AssertionError;NoClassDefFoundError;Exception;RuntimeException;ExceptionInInitializerError'
#  'StackOverflowError' 'SyntaxError' 'UnsupportedOperationException'
#  'IOError' 'DeprecationWarning' 'PSQLException' 'IllegalArgumentException'
#  'ClassNotFoundException' 'RestClientResponseException'
#  'HttpMessageNotReadableException;RestClientException;MismatchedInputException'
#  'AssertionError;AssertionFailedError' 'TooManyActualInvocations'
#  'NullPointerException;AssertionError' 'RuntimeError' 'NoSuchMethodError'
#  'BeanInstantiationException;ClassNotFoundException;BeanCreationException;IllegalStateException;NoClassDefFoundError'
#  'FileNotFoundException' 'DataIntegrityViolationException'
#  'UnknownHostException' 'AssertionError;UnicodeDecodeError'
#  'ZeroDivisionError'
#  'NullPointerException;URISyntaxException;IllegalArgumentException'
#  'AuthenticationFailedException' 'IndexError'
#  'UnsupportedClassVersionError;NoClassDefFoundError'
#  'ClassNotFoundException;IllegalStateException;Exception;UnsupportedClassVersionError'
#  'AssertionError;NoSuchMethodException;NoClassDefFoundError'
#  'SocketException;AssertionError'
#  'AssertionFailedError;IllegalArgumentException' 'OSError'
#  'DAGTraversalException;NullPointerException'
#  'InvocationTargetException;NullPointerException'
#  'AuthenticationException'
#  'InvocationTargetException;NoClassDefFoundError;UnsatisfiedLinkError'
#  'JSONException' 'CalledProcessError'
#  'RuntimeException;NullPointerException' 'OSError;AttributeError'
#  'NullPointerException;SemanticIndexException;SAXParseException'
#  'NameError' 'NotImplementedError' 'BeanCreationException'
#  'NoSessionException;MultiSessionException'
#  'NullPointerException;SpreadsheetLoadException;YamcsException'
#  'ExceptionInInitializerError'
#  'ConfigurationException;NullPointerException' 'RuntimeException'
#  'AssertionError;TypeError' 'AssertionError;NullPointerException'
#  'ValueError;AssertionError' 'AccessDeniedException'
#  'AssertionError;TypeError;AttributeError'
#  'AssertionFailedError;NullPointerException'
#  'RuntimeException;ArkRuntimeException;NullPointerException'
#  'InvalidClassException'
#  'AssertionError;IllegalStateException;RuntimeException'
#  'ClassCastException'
#  'AssertionFailedError;RuntimeException;InvalidInputException;IsNaNException;TooManyIterationsException'
#  'NoSuchFileException' 'ComparisonFailure;AssertionError'
#  'NullPointerException;IllegalStateException;UnsupportedOperationException'
#  'TemplateSyntaxError' 'InjectMocksException;NullPointerException'
#  'IllegalStateException;AssertionError'
#  'ProvisionException;ComponentLookupException'
#  'ExceptionDuringRun;SyntaxError'
#  'RepositoryException;AccessControlException;PathNotFoundException;AssertionFailedError;NullPointerException;RuntimeException;NamespaceException;AssertionError'
#  'AssertionError;AttributeError' 'BundleException' 'RazorpayException'
#  'ComparisonFailure;NullPointerException'
#  'BeanInstantiationException;ClassNotFoundException;BeanCreationException;NoClassDefFoundError;UnsatisfiedDependencyException'
#  'ArgumentsAreDifferent'
#  'IllegalArgumentException;InvalidDefinitionException'
#  'PipeRunException;ExecutionException;NullPointerException'
#  'IndexOutOfBoundsException' 'AssertionError;PathNotFoundException'
#  'ImportError;AttributeError' 'SAXParseException'
#  'IOException;AssertionError'
#  'ClassNotFoundException;NoClassDefFoundError' 'IndexError;AssertionError'
#  'IllegalAccessException;NullPointerException;RuntimeException;NoClassDefFoundError;ExceptionInInitializerError'
#  'NullPointerException;WantedButNotInvoked' 'Exception'
#  'IOError;AttributeError' 'NullPointerException;ComparisonFailure'
#  'AssertFailedException' 'HeadlessException'
#  'ExpectationError;UnexpectedInvocation;Exception' 'RuntimeWarning'
#  'BeanInstantiationException;UnsupportedClassVersionError;BeanCreationException;UnsatisfiedDependencyException'
#  'WantedButNotInvoked;AssertionError'
#  'InvocationTargetException;SpecInstantiationException;RuntimeException;AssertionError;AssertionFailedError'
#  'AssertionError;ExceptionInInitializerError'
#  'IllegalStateException;NullPointerException' 'InterruptedIOException'
#  'BeanCreationException;IllegalStateException' 'VerifyError'
#  'AmqpResourceNotAvailableException'
#  'Error;AbstractMethodError;NullPointerException'
#  'SSLPeerUnverifiedException;AssertionError;SocketTimeoutException'
#  'AssertionError;RuntimeException;NoSuchMethodException'
#  'YamcsApiException' 'AssertionError;RuntimeWarning'
#  'ComparisonFailure;AssertionError;ArrayStoreException' 'BadValueError'
#  'CommonException' 'RuntimeException;IllegalArgumentException'
#  'NoSuchFieldError;AssertionError'
#  'ArrayIndexOutOfBoundsException;AssertionError' 'EOFException'
#  'NullPointerException;AssertionFailedError;AssertionError'
#  'AssertionFailedError;AssertionError' 'KeyError'
#  'VerificationInOrderFailure' 'timeout;SSHException'
#  'AssertionFailedError;JSONException;ComparisonFailure;IllegalStateException;ClassCastException;JSONValidException'
#  'IOException' 'SphinxWarning'
#  'InvocationTargetException;SpecInstantiationException;RuntimeException;BeforeSpecException;AssertionError;AssertionFailedError'
#  'UnnecessaryStubbingException;NullPointerException'
#  'NullPointerException;ExecutionException;YamcsApiException'
#  'ProvisionException;IOException;RuntimeException;ExecutionException'
#  'ValidationError;AssertionError' 'TimeoutException;RuntimeException'
#  'NullPointerException;IndexingException'
#  'AssertionError;FileNotFoundError'
#  'AssertionError;NestedServletException;NullPointerException'
#  'ProtocolException;AssertionError'
#  'OnErrorNotImplementedException;SQLRuntimeException'
#  'CompositeException;OnErrorNotImplementedException;SQLRuntimeException'
#  'IllegalStateException;Exception'
#  'NoUniqueBeanDefinitionException;ComparisonFailure;TestTimedOutException;AssertionError'
#  'NullPointerException;AssertionError;IllegalArgumentException'
#  'ImportError;AssertionError' 'ExecutionException;AssertionError'
#  'NullPointerException;IllegalArgumentException'
#  'AssertionFailedError;JSONException' 'KryoException;NullPointerException'
#  'IIOException' 'ThrowableAssertionError'
#  'BeanInstantiationException;BeanCreationException;IllegalStateException;DataSourceBeanCreationException;UnsatisfiedDependencyException'
#  'NumberFormatException' 'SchemaValidationError'
#  'UncheckedJannovarException' 'UnsupportedClassVersionError'
#  'IllegalStateException;IllegalArgumentException' 'ConnectException'
#  'AssertionError;NoInteractionsWanted'
#  'UnsupportedOperationException;AssertionError' 'ValueError;IOError'
#  'RuntimeException;IllegalStateException;AssertionError'
#  'NoSuchElementException;AssertionError' 'DeploymentException'
#  'NoSuchFieldError' 'QueryEvaluationException;OBDAException'
#  'AssertionFailedError;ArrayIndexOutOfBoundsException;NegativeArraySizeException'
#  'NotRecognizedRedeemScript;KeyError;IndexError'
#  'SenderException;NullPointerException;AssertionError;TransformerException'
#  'HostedModeException;RuntimeException;InternalCompilerException;ExceptionInInitializerError'
#  'ExceptionDuringRun;ImportError'
#  'ConfigurationException;ClassNotFoundException'
#  'AssertionError;BadRequestKeyError;UnicodeDecodeError'
#  'ExecutionException;AssertionError;SuspendExecution']
